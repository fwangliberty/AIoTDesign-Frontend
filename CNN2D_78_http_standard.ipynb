# %% [markdown]
# <a href="https://colab.research.google.com/github/fwangliberty/AIoTDesign-Frontend/blob/master/CNN2D_78_http_standard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN2D for CICIDS 2017 Data Set with 78 Features including Http flag

# %% [markdown]
# We investigate the effect of adding "is_http80" on the detection results.

# %%
import os
from os.path import join
import glob
import pandas as pd
import numpy as np
import time
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def display_metrics(y_test, y_pred, label_names):
  print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_test, y_pred)))

  print('Micro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='micro')))
  print('Micro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='micro')))
  print('Micro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='micro')))

  print('Macro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='macro')))
  print('Macro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='macro')))
  print('Macro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='macro')))

  print('Weighted Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='weighted')))
  print('Weighted Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='weighted')))
  print('Weighted F1-score: {:.2f}'.format(f1_score(y_test, y_pred, average='weighted')))

  print('\nClassification Report\n')
  print(classification_report(y_test, y_pred, target_names=label_names))

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 100, "display.max_columns", 100): 
        print(df)

# %%
def make_value2index(attacks):
    #make dictionary
    attacks = sorted(attacks)
    d = {}
    counter=0
    for attack in attacks:
        d[attack] = counter
        counter+=1
    return d

# %%
# chganges label from string to integer/index
def encode_label(Y_str):
    labels_d = make_value2index(np.unique(Y_str))
    Y = [labels_d[y_str] for y_str  in Y_str]
    Y = np.array(Y)
    return np.array(Y)

# %% [markdown]
# ## Step 1. Loading csv files

# %%
# All columns
col_names = np.array(['dst sport count', 'src dport count', 'dst src count', 'dport count', 'sport count', 'dst host count','src host count','Source Port', 'Destination Port',
                      'Protocol', 'Flow Duration', 'Total Fwd Packets', 'Total Backward Packets', 'Total Length of Fwd Packets',
                      'Total Length of Bwd Packets', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean',
                      'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std',
                      'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total',
                      'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max',
                      'Bwd IAT Min', 'Fwd PSH Flags', 'Fwd URG Flags', 'Fwd Header Length', 'Bwd Header Length',
                      'Fwd Packets/s', 'Bwd Packets/s', 'Min Packet Length', 'Max Packet Length', 'Packet Length Mean', 'Packet Length Std',
                      'Packet Length Variance', 'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count',
                      'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio', 'Average Packet Size', 'Avg Fwd Segment Size',
                      'Avg Bwd Segment Size','Subflow Fwd Packets', 'Subflow Fwd Bytes',
                      'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward', 'Init_Win_bytes_backward',
                      'act_data_pkt_fwd', 'min_seg_size_forward', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean',
                      'Idle Std', 'Idle Max', 'Idle Min', 'Label'])

# %% [markdown]
# ### Option 1. Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# load three csv files generated by mlp4nids (Multi-layer perceptron for network intrusion detection )
# first load the train set
df_train = pd.read_csv('/content/drive/My Drive/CICIDS2017/train_set_ext78_2.csv',names=col_names, skiprows=1)

# %%
print('Train set size: ', df_train.shape)
# Out:
# Train set size:  (879589, 79)

# %%
df_test = pd.read_csv('/content/drive/My Drive/CICIDS2017/test_set_ext78_2.csv',names=col_names, skiprows=1)  
print('Test set size: ', df_test.shape)

df_val = pd.read_csv('/content/drive/My Drive/CICIDS2017/crossval_set_ext78_2.csv',names=col_names, skiprows=1)  
print('Validation set size: ', df_val.shape)
# Out:
# Test set size:  (188483, 79)
# Validation set size:  (188484, 79)

# %% [markdown]
# ### Option 2. Load from local machine

# %%
dataroot = '../data/train_set_ext78_2.csv'
df_train = pd.read_csv(dataroot, names=col_names, skiprows=1)

# %%
dataroot = '../data/crossval_set_ext78_2.csv'
df_val = pd.read_csv(dataroot, names=col_names, skiprows=1) 
dataroot = '../data/test_set_ext78_2.csv'
df_test = pd.read_csv(dataroot, names=col_names, skiprows=1)

# %% [markdown]
# ## Step 2. Exploring the dataset

# %%
df_train.head()
# Out:
#    dst sport count  src dport count  dst src count  ...  Idle Max  Idle Min   Label
# 0                2              100            100  ...  85700000  12200000    DDoS
# 1                2               23             13  ...         0         0  BENIGN
# 2                1                2              3  ...         0         0  BENIGN
# 3                2                1              2  ...         0         0  BENIGN
# 4                2                4              2  ...         0         0  BENIGN
#
# [5 rows x 79 columns]

# %% [markdown]
# Count the number of attacks

# %%
df_train['Label'].value_counts()
# Out:
# BENIGN                        490029
# DoS Hulk                      161134
# PortScan                      110992
# DDoS                           89590
# DoS GoldenEye                   7220
# FTP-Patator                     5621
# SSH-Patator                     4153
# DoS slowloris                   4049
# DoS Slowhttptest                3833
# Bot                             1401
# Web Attack � Brute Force        1059
# Web Attack � XSS                 463
# Infiltration                      25
# Web Attack � Sql Injection        12
# Heartbleed                         8
# Name: Label, dtype: int64

# %%
df_train.describe()
# Out:
#        dst sport count  src dport count  ...      Idle Max      Idle Min
# count    556548.000000    556548.000000  ...  5.565480e+05  5.565480e+05
# mean         17.404549        45.110869  ...  1.730500e+07  1.552621e+07
# std          35.384468        42.638613  ...  3.390042e+07  3.259279e+07
# min           1.000000         1.000000  ...  0.000000e+00  0.000000e+00
# 25%           1.000000         1.000000  ...  0.000000e+00  0.000000e+00
# 50%           1.000000        28.000000  ...  0.000000e+00  0.000000e+00
# 75%           2.000000        98.000000  ...  9.803576e+06  7.462839e+06
# max         100.000000       100.000000  ...  1.200000e+08  1.200000e+08
#
# [8 rows x 78 columns]

# %% [markdown]
# Read test and validation sets

# %%
print('Test set: ')
df_test['Label'].value_counts()
# Out:
# Test set:
# BENIGN                        139135
# DoS Hulk                       57531
# PortScan                       39701
# DDoS                           32006
# DoS GoldenEye                   2573
# FTP-Patator                     1983
# SSH-Patator                     1474
# DoS slowloris                   1449
# DoS Slowhttptest                1374
# Bot                              489
# Web Attack � Brute Force         376
# Web Attack � XSS                 163
# Infiltration                       9
# Web Attack � Sql Injection         5
# Heartbleed                         3
# Name: Label, dtype: int64

# %%
df_test.describe()
# Out:
#        dst sport count  src dport count  ...      Idle Max      Idle Min
# count    278271.000000    278271.000000  ...  2.782710e+05  2.782710e+05
# mean          9.211463        41.570207  ...  1.461178e+07  1.319741e+07
# std          24.647299        40.590060  ...  3.158808e+07  3.024676e+07
# min           1.000000         1.000000  ...  0.000000e+00  0.000000e+00
# 25%           1.000000         2.000000  ...  0.000000e+00  0.000000e+00
# 50%           1.000000        25.000000  ...  0.000000e+00  0.000000e+00
# 75%           2.000000        94.000000  ...  5.860436e+06  5.499876e+06
# max         100.000000       100.000000  ...  1.199946e+08  1.199946e+08
#
# [8 rows x 78 columns]

# %%
print('Validation set: ')
df_val['Label'].value_counts()
# Out:
# Validation set:
# BENIGN                        139135
# DoS Hulk                       57531
# PortScan                       39701
# DDoS                           32006
# DoS GoldenEye                   2573
# FTP-Patator                     1983
# SSH-Patator                     1474
# DoS slowloris                   1449
# DoS Slowhttptest                1374
# Bot                              489
# Web Attack � Brute Force         376
# Web Attack � XSS                 163
# Infiltration                       9
# Web Attack � Sql Injection         5
# Heartbleed                         3
# Name: Label, dtype: int64

# %%
df_val.describe()
# Out:
#        dst sport count  src dport count  ...      Idle Max      Idle Min
# count    278271.000000    278271.000000  ...  2.782710e+05  2.782710e+05
# mean          1.990998        42.802930  ...  1.829748e+07  1.689399e+07
# std           4.265641        41.155317  ...  3.540416e+07  3.437326e+07
# min           1.000000         1.000000  ...  0.000000e+00  0.000000e+00
# 25%           1.000000         2.000000  ...  0.000000e+00  0.000000e+00
# 50%           1.000000        26.000000  ...  0.000000e+00  0.000000e+00
# 75%           1.000000        97.000000  ...  9.992128e+06  7.454084e+06
# max          59.000000       100.000000  ...  1.200000e+08  1.200000e+08
#
# [8 rows x 78 columns]

# %% [markdown]
# # 3. Adding Is_Http Feature

# %%
http_port = [80]

# %%
df_train.insert(1, "is_http80", "") 
df_val.insert(1, "is_http80", "") 
df_test.insert(1, "is_http80", "")

# %%
for i, row in df_train.iterrows():
    if row['Destination Port'] in http_port:
        df_train.at[i, 'is_http80'] = 1
    else:
        df_train.at[i, 'is_http80'] =  0

# %%
for i, row in df_val.iterrows():
    if row['Destination Port'] in http_port:
        df_val.at[i, 'is_http80'] = 1
    else:
        df_val.at[i, 'is_http80'] =  0

# %%
for i, row in df_test.iterrows():
    if row['Destination Port'] in http_port:
        df_test.at[i, 'is_http80'] = 1
    else:
        df_test.at[i, 'is_http80'] =  0

# %% [markdown]
# ## Step 4. Encode Datasets

# %% [markdown]
# Encoding the labels, and generate numpy array. Note that the label has not been encoded as one-hot coding. We will use one-hot code later.

# %% [markdown]
# ### Step 4.1 Encoding train dataset

# %%
df_label = df_train['Label']
data = df_train.drop(columns=['Label'])
Xtrain = data.values
y_train = encode_label(df_label.values)

# %% [markdown]
# ### Step 4.2. Encoding test dataset

# %%
df_label = df_test['Label']
data = df_test.drop(columns=['Label'])
Xtest = data.values
y_test = encode_label(df_label.values)

# %% [markdown]
# ### Step 4.3 Encoding validation dataset

# %%
df_label = df_val['Label']
data = df_val.drop(columns=['Label'])
Xval = data.values
y_val = encode_label(df_label.values)

# %% [markdown]
# ## Step 5. Normalization or Standardization
#
# The continuous feature values are normalized into the same feature space. This is important when using features that have different measurements, and is a general requirement of many machine learning algorithms. We implement the two methods to see the impact on the final classifications.

# %% [markdown]
# ## Option 1. Normalization
#
# The values of the datasets are normalized using the Min-Max scaling technique, bringing them all within a range of [0,1].

# %% [markdown]
# ### Step 5.1 Normalizing train dataset

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(Xtrain)
X_train
# Out:
# array([[7.66048676e-01, 5.93603125e-03, 1.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [7.29167620e-01, 1.22077764e-03, 3.52941176e-01, ...,
#         0.00000000e+00, 7.12500000e-01, 7.12500000e-01],
#        [7.86144808e-01, 6.76005616e-03, 3.52941176e-01, ...,
#         8.96864890e-03, 4.90833333e-01, 4.83333333e-01],
#        ...,
#        [2.53009842e-01, 1.22077764e-03, 3.52941176e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [7.85610742e-01, 8.08765183e-04, 1.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [8.26276036e-01, 1.22077764e-03, 3.52941176e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %% [markdown]
# ### Step 5.2. Normalizing validation dataset

# %%
X_val = scaler.fit_transform(Xval)
X_val
# Out:
# array([[4.37994965e-01, 1.22344737e-03, 3.52941176e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [8.41290913e-01, 6.12488339e-02, 3.52941176e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.87327382e-02, 6.77483980e-03, 3.52941176e-01, ...,
#         5.68691207e-05, 8.33333333e-02, 8.32947583e-02],
#        ...,
#        [9.30510414e-01, 8.10533882e-04, 1.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [6.50492103e-01, 8.68494701e-02, 3.52941176e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.24353399e-01, 1.22344737e-03, 3.52941176e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %% [markdown]
# ### Step 5.3. Normalizing test dataset

# %%
X_test = scaler.fit_transform(Xtest)
X_test
# Out:
# array([[5.45487838e-01, 9.66383862e-01, 3.52941176e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [9.17142247e-01, 1.22074038e-03, 3.52941176e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [7.92001099e-01, 7.97448653e-02, 3.52941176e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [9.04507584e-01, 1.22074038e-03, 3.52941176e-01, ...,
#         0.00000000e+00, 8.33370661e-01, 8.33370661e-01],
#        [9.22345653e-01, 8.08740501e-04, 1.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [5.45030061e-01, 6.75984985e-03, 3.52941176e-01, ...,
#         5.01804492e-03, 4.88761059e-01, 4.84412289e-01]])

# %% [markdown]
# ## Option 2. Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(Xtrain)
X_val = scaler.fit_transform(Xval)
X_test = scaler.fit_transform(Xtest)

X_train
# Out:
# array([[-0.29659729,  1.32790313,  1.51710965, ...,  8.4581104 ,
#          2.22140524, -0.0393603 ],
#        [-0.29659729,  1.32790313, -0.36301636, ..., -0.13390608,
#         -0.45746381, -0.43398332],
#        [-0.33534125, -0.75306698, -0.87577799, ..., -0.13390608,
#         -0.45746381, -0.43398332],
#        ...,
#        [-0.33534125, -0.75306698, -0.60718856, ..., -0.13390608,
#         -0.45746381, -0.43398332],
#        [-0.33534125,  1.32790313,  1.224103  , ..., -0.13390608,
#         -0.45746381, -0.43398332],
#        [ 3.50031109, -0.75306698, -0.90019522, ..., -0.13390608,
#         -0.45746381, -0.43398332]])

# %% [markdown]
# ## Step 6 One-hot encoding for labels

# %% [markdown]
# y_train, y_test and y_val have to be one-hot-encoded. That means they must have dimension (number_of_samples, 15), where 15 denotes number of classes.

# %%
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Save the labels for AdaBoostClassifier

# %%
y_train_ada = y_train
y_test_ada = y_test
y_val_ada = y_val

# %%
y_train = to_categorical(y_train, 15)
y_test = to_categorical(y_test, 15)
y_val = to_categorical(y_val, 15)

# %% [markdown]
# ## Step 7. Define the metrics

# %%
import tensorflow as tf
from sklearn.ensemble import RandomForestClassifier

#importing confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from sklearn import metrics
from sklearn.metrics import accuracy_score

#importing accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
METRICS = [
      tf.keras.metrics.TruePositives(name='tp'),
      tf.keras.metrics.FalsePositives(name='fp'),
      tf.keras.metrics.TrueNegatives(name='tn'),
      tf.keras.metrics.FalseNegatives(name='fn'), 
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc'),
]

# %% [markdown]
# Get the attacks' names

# %%
labels_d = make_value2index(df_test['Label'])

# %%
print(labels_d)
# Out:
# {'BENIGN': 105018, 'Bot': 105298, 'DDoS': 124569, 'DoS GoldenEye': 126111, 'DoS Hulk': 160658, 'DoS Slowhttptest': 161486, 'DoS slowloris': 162320, 'FTP-Patator': 163498, 'Heartbleed': 163500, 'Infiltration': 163501, 'PortScan': 187347, 'SSH-Patator': 188173, 'Web Attack � Brute Force': 188382, 'Web Attack � Sql Injection': 188389, 'Web Attack � XSS': 188482}

# %% [markdown]
# # CNN2D Model

# %% [markdown]
# ## Convert each example as a 8x10 gray image since each example has 79 features by adding a new empty feature

# %%
X_train_enlarge = np.append(X_train, np.zeros([len(X_train),1]),1)
X_val_enlarge = np.append(X_val, np.zeros([len(X_val),1]),1)
X_test_enlarge = np.append(X_test, np.zeros([len(X_test),1]),1)

# %%
img_row = 8
img_col = 10

X_train_gray = np.array([x.reshape(img_row, img_col,1) for x in X_train_enlarge])
train_gray = np.array([x.reshape(img_row, img_col) for x in X_train_enlarge])

# %%
X_test_gray = np.array([x.reshape(img_row, img_col,1) for x in X_test_enlarge])
test_gray = np.array([x.reshape(img_row, img_col) for x in X_test_enlarge])

# %%
X_val_gray = np.array([x.reshape(img_row, img_col,1) for x in X_val_enlarge])
val_gray =  np.array([x.reshape(img_row, img_col) for x in X_val_enlarge])

# %%
X_train_gray.shape
# Out:
# (879589, 8, 10, 1)

# %%
X_test_gray.shape
# Out:
# (188483, 8, 10, 1)

# %%
n = 40  # how many digits we will display
plt.figure(figsize=(80, 30))
for i in range(1,10):
    # display original
    ax = plt.subplot(1, n, i + 1)
    plt.imshow(train_gray[i])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
plt.close()

# %%
n = 40  # how many digits we will display
plt.figure(figsize=(80, 30))
for i in range(1,10):
    # display original
    ax = plt.subplot(1, n, i + 1)
    plt.imshow(test_gray[i])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
plt.close()

# %%
n = 40  # how many digits we will display
plt.figure(figsize=(80, 30))
for i in range(1,10):
    # display original
    ax = plt.subplot(1, n, i + 1)
    plt.imshow(val_gray[i])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
plt.close()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Flatten, Dense, Activation,Dropout
from tensorflow.keras.constraints import max_norm

# %%
#hyper-params
batch_size =100 # increasing batch size with more gpu added
input_dim = X_train.shape[1]
num_class = 15                   # 15 intrusion classes, including benign traffic class
num_epochs = 30
learning_rates = 1e-4
regularizations = 1e-3
optim = tf.keras.optimizers.Adam(lr=learning_rates, beta_1=0.9, beta_2=0.999, epsilon=1e-8)

print(input_dim)
print(num_class)
# Out:
# 79
# 15

# %%
model2d_g = Sequential()
model2d_g.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(8,10,1)))
model2d_g.add(Conv2D(64, kernel_size=(3 ,3), padding='same',  activation='relu'))
model2d_g.add(Conv2D(128, kernel_size=(3,3), padding='same',  activation='relu'))
model2d_g.add(Flatten())
model2d_g.add(Dropout(0.2))
model2d_g.add(Dense(512))
model2d_g.add(Dense(num_class, activation='softmax'))
 
model2d_g.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 8, 10, 32)         320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 10, 64)         18496
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 10, 128)        73856
# _________________________________________________________________
# flatten (Flatten)            (None, 10240)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 10240)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               5243392
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                7695
# =================================================================
# Total params: 5,343,759
# Trainable params: 5,343,759
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import Nadam, Adam, RMSprop
from keras.callbacks import LearningRateScheduler, ModelCheckpoint
import keras
import time
time_start = time.time()

reduce_lr = keras.callbacks.ReduceLROnPlateau(moniter='val_loss',
                                              factor=0.1,
                                              patience=10)
nadam = Nadam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, schedule_decay=0.0001)
model2d_g.compile(loss = "categorical_crossentropy",optimizer = "nadam", metrics = METRICS)
#model2d_g.compile(loss='categorical_crossentropy',
#              optimizer= RMSprop(lr=0.001), #,SGD(lr=0.01), #
#              metrics=METRICS)

#model2d_g.compile(
#      optimizer= Adam(lr=1e-4),
#      loss=tf.keras.losses.BinaryCrossentropy(),
#      loss='categorical_crossentropy',
#      metrics=METRICS)

history = model2d_g.fit(X_train_gray, y_train, 
                    epochs=20, 
                    batch_size=batch_size, 
                    verbose=2,
                    validation_data=(X_val_gray, y_val),
                    callbacks=[reduce_lr])
time_end = time.time()
train_time = time_end - time_start
print("train_time:",train_time)
# Out:
# Epoch 1/20
# 8796/8796 - 198s - loss: 0.0149 - tp: 1063629.0000 - fp: 4349.0000 - tn: 14948659.0000 - fn: 4443.0000 - accuracy: 0.9995 - precision: 0.9959 - recall: 0.9958 - auc: 0.9998 - val_loss: 0.0147 - val_tp: 187739.0000 - val_fp: 718.0000 - val_tn: 2638058.0000 - val_fn: 745.0000 - val_accuracy: 0.9995 - val_precision: 0.9962 - val_recall: 0.9960 - val_auc: 0.9999
# Epoch 2/20
# 8796/8796 - 195s - loss: 0.0150 - tp: 875442.0000 - fp: 4051.0000 - tn: 12310195.0000 - fn: 4147.0000 - accuracy: 0.9994 - precision: 0.9954 - recall: 0.9953 - auc: 0.9999 - val_loss: 0.0198 - val_tp: 187704.0000 - val_fp: 777.0000 - val_tn: 2637999.0000 - val_fn: 780.0000 - val_accuracy: 0.9994 - val_precision: 0.9959 - val_recall: 0.9959 - val_auc: 0.9997
# Epoch 3/20
# 8796/8796 - 195s - loss: 0.0145 - tp: 875499.0000 - fp: 4001.0000 - tn: 12310245.0000 - fn: 4090.0000 - accuracy: 0.9994 - precision: 0.9955 - recall: 0.9954 - auc: 0.9999 - val_loss: 0.0240 - val_tp: 187542.0000 - val_fp: 912.0000 - val_tn: 2637864.0000 - val_fn: 942.0000 - val_accuracy: 0.9993 - val_precision: 0.9952 - val_recall: 0.9950 - val_auc: 0.9997
# Epoch 4/20
# 8796/8796 - 195s - loss: 0.0149 - tp: 875438.0000 - fp: 4058.0000 - tn: 12310188.0000 - fn: 4151.0000 - accuracy: 0.9994 - precision: 0.9954 - recall: 0.9953 - auc: 0.9998 - val_loss: 0.0151 - val_tp: 187742.0000 - val_fp: 724.0000 - val_tn: 2638052.0000 - val_fn: 742.0000 - val_accuracy: 0.9995 - val_precision: 0.9962 - val_recall: 0.9961 - val_auc: 0.9999
# Epoch 5/20
# 8796/8796 - 194s - loss: 0.0158 - tp: 875495.0000 - fp: 3979.0000 - tn: 12310267.0000 - fn: 4094.0000 - accuracy: 0.9994 - precision: 0.9955 - recall: 0.9953 - auc: 0.9998 - val_loss: 0.0154 - val_tp: 187654.0000 - val_fp: 790.0000 - val_tn: 2637986.0000 - val_fn: 830.0000 - val_accuracy: 0.9994 - val_precision: 0.9958 - val_recall: 0.9956 - val_auc: 0.9999
# Epoch 6/20
# 8796/8796 - 194s - loss: 0.0152 - tp: 875317.0000 - fp: 4164.0000 - tn: 12310082.0000 - fn: 4272.0000 - accuracy: 0.9994 - precision: 0.9953 - recall: 0.9951 - auc: 0.9998 - val_loss: 0.0179 - val_tp: 187645.0000 - val_fp: 833.0000 - val_tn: 2637943.0000 - val_fn: 839.0000 - val_accuracy: 0.9994 - val_precision: 0.9956 - val_recall: 0.9955 - val_auc: 0.9998
# Epoch 7/20
# 8796/8796 - 194s - loss: 0.0168 - tp: 875409.0000 - fp: 4085.0000 - tn: 12310161.0000 - fn: 4180.0000 - accuracy: 0.9994 - precision: 0.9954 - recall: 0.9952 - auc: 0.9998 - val_loss: 0.0197 - val_tp: 187598.0000 - val_fp: 863.0000 - val_tn: 2637913.0000 - val_fn: 886.0000 - val_accuracy: 0.9994 - val_precision: 0.9954 - val_recall: 0.9953 - val_auc: 0.9998
# Epoch 8/20
# 8796/8796 - 195s - loss: 0.0153 - tp: 875358.0000 - fp: 4098.0000 - tn: 12310148.0000 - fn: 4231.0000 - accuracy: 0.9994 - precision: 0.9953 - recall: 0.9952 - auc: 0.9998 - val_loss: 0.0181 - val_tp: 187575.0000 - val_fp: 896.0000 - val_tn: 2637880.0000 - val_fn: 909.0000 - val_accuracy: 0.9994 - val_precision: 0.9952 - val_recall: 0.9952 - val_auc: 0.9998
# Epoch 9/20
# 8796/8796 - 196s - loss: 0.0143 - tp: 875512.0000 - fp: 3968.0000 - tn: 12310278.0000 - fn: 4077.0000 - accuracy: 0.9994 - precision: 0.9955 - recall: 0.9954 - auc: 0.9998 - val_loss: 0.0214 - val_tp: 187630.0000 - val_fp: 848.0000 - val_tn: 2637928.0000 - val_fn: 854.0000 - val_accuracy: 0.9994 - val_precision: 0.9955 - val_recall: 0.9955 - val_auc: 0.9997
# Epoch 10/20
# 8796/8796 - 195s - loss: 0.0159 - tp: 875430.0000 - fp: 4041.0000 - tn: 12310205.0000 - fn: 4159.0000 - accuracy: 0.9994 - precision: 0.9954 - recall: 0.9953 - auc: 0.9998 - val_loss: 0.0197 - val_tp: 187687.0000 - val_fp: 794.0000 - val_tn: 2637982.0000 - val_fn: 797.0000 - val_accuracy: 0.9994 - val_precision: 0.9958 - val_recall: 0.9958 - val_auc: 0.9998
# Epoch 11/20
# 8796/8796 - 195s - loss: 0.0144 - tp: 875437.0000 - fp: 4039.0000 - tn: 12310207.0000 - fn: 4152.0000 - accuracy: 0.9994 - precision: 0.9954 - recall: 0.9953 - auc: 0.9999 - val_loss: 0.0187 - val_tp: 187712.0000 - val_fp: 739.0000 - val_tn: 2638037.0000 - val_fn: 772.0000 - val_accuracy: 0.9995 - val_precision: 0.9961 - val_recall: 0.9959 - val_auc: 0.9998
# Epoch 12/20
# 8796/8796 - 195s - loss: 0.0090 - tp: 876698.0000 - fp: 2814.0000 - tn: 12311432.0000 - fn: 2891.0000 - accuracy: 0.9996 - precision: 0.9968 - recall: 0.9967 - auc: 1.0000 - val_loss: 0.0148 - val_tp: 187910.0000 - val_fp: 564.0000 - val_tn: 2638212.0000 - val_fn: 574.0000 - val_accuracy: 0.9996 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 0.9999
# Epoch 13/20
# 8796/8796 - 195s - loss: 0.0077 - tp: 877034.0000 - fp: 2477.0000 - tn: 12311769.0000 - fn: 2555.0000 - accuracy: 0.9996 - precision: 0.9972 - recall: 0.9971 - auc: 1.0000 - val_loss: 0.0132 - val_tp: 187940.0000 - val_fp: 528.0000 - val_tn: 2638248.0000 - val_fn: 544.0000 - val_accuracy: 0.9996 - val_precision: 0.9972 - val_recall: 0.9971 - val_auc: 0.9999
# Epoch 14/20
# 8796/8796 - 195s - loss: 0.0072 - tp: 877140.0000 - fp: 2380.0000 - tn: 12311866.0000 - fn: 2449.0000 - accuracy: 0.9996 - precision: 0.9973 - recall: 0.9972 - auc: 1.0000 - val_loss: 0.0132 - val_tp: 187982.0000 - val_fp: 490.0000 - val_tn: 2638286.0000 - val_fn: 502.0000 - val_accuracy: 0.9996 - val_precision: 0.9974 - val_recall: 0.9973 - val_auc: 0.9999
# Epoch 15/20
# 8796/8796 - 195s - loss: 0.0071 - tp: 877188.0000 - fp: 2328.0000 - tn: 12311918.0000 - fn: 2401.0000 - accuracy: 0.9997 - precision: 0.9974 - recall: 0.9973 - auc: 1.0000 - val_loss: 0.0132 - val_tp: 188001.0000 - val_fp: 469.0000 - val_tn: 2638307.0000 - val_fn: 483.0000 - val_accuracy: 0.9997 - val_precision: 0.9975 - val_recall: 0.9974 - val_auc: 0.9999
# Epoch 16/20
# 8796/8796 - 196s - loss: 0.0072 - tp: 877308.0000 - fp: 2211.0000 - tn: 12312035.0000 - fn: 2281.0000 - accuracy: 0.9997 - precision: 0.9975 - recall: 0.9974 - auc: 1.0000 - val_loss: 0.0135 - val_tp: 187968.0000 - val_fp: 507.0000 - val_tn: 2638269.0000 - val_fn: 516.0000 - val_accuracy: 0.9996 - val_precision: 0.9973 - val_recall: 0.9973 - val_auc: 0.9999
# Epoch 17/20
# 8796/8796 - 197s - loss: 0.0066 - tp: 877336.0000 - fp: 2200.0000 - tn: 12312046.0000 - fn: 2253.0000 - accuracy: 0.9997 - precision: 0.9975 - recall: 0.9974 - auc: 1.0000 - val_loss: 0.0130 - val_tp: 187991.0000 - val_fp: 479.0000 - val_tn: 2638297.0000 - val_fn: 493.0000 - val_accuracy: 0.9997 - val_precision: 0.9975 - val_recall: 0.9974 - val_auc: 0.9999
# Epoch 18/20
# 8796/8796 - 196s - loss: 0.0065 - tp: 877337.0000 - fp: 2186.0000 - tn: 12312060.0000 - fn: 2252.0000 - accuracy: 0.9997 - precision: 0.9975 - recall: 0.9974 - auc: 1.0000 - val_loss: 0.0128 - val_tp: 187991.0000 - val_fp: 489.0000 - val_tn: 2638287.0000 - val_fn: 493.0000 - val_accuracy: 0.9996 - val_precision: 0.9974 - val_recall: 0.9974 - val_auc: 0.9999
# Epoch 19/20
# 8796/8796 - 196s - loss: 0.0065 - tp: 877380.0000 - fp: 2146.0000 - tn: 12312100.0000 - fn: 2209.0000 - accuracy: 0.9997 - precision: 0.9976 - recall: 0.9975 - auc: 1.0000 - val_loss: 0.0127 - val_tp: 187987.0000 - val_fp: 491.0000 - val_tn: 2638285.0000 - val_fn: 497.0000 - val_accuracy: 0.9996 - val_precision: 0.9974 - val_recall: 0.9974 - val_auc: 0.9999
# Epoch 20/20
# 8796/8796 - 194s - loss: 0.0063 - tp: 877392.0000 - fp: 2115.0000 - tn: 12312131.0000 - fn: 2197.0000 - accuracy: 0.9997 - precision: 0.9976 - recall: 0.9975 - auc: 1.0000 - val_loss: 0.0134 - val_tp: 188003.0000 - val_fp: 466.0000 - val_tn: 2638310.0000 - val_fn: 481.0000 - val_accuracy: 0.9997 - val_precision: 0.9975 - val_recall: 0.9974 - val_auc: 0.9999
# train_time: 3905.457797050476

# %% [markdown]
# ## Get the metrics

# %%
# evaluate model
accuracy = model2d_g.evaluate(X_test_gray, y_test, batch_size=batch_size, verbose=1)
# Out:
# 1885/1885 [==============================] - 21s 11ms/step - loss: 0.0108 - tp: 188053.0000 - fp: 423.0000 - tn: 2638339.0000 - fn: 430.0000 - accuracy: 0.9997 - precision: 0.9978 - recall: 0.9977 - auc: 0.9999

# %%
y_pred=model2d_g.predict(X_test_gray)

# %%
display_metrics(y_test_ada, np.argmax(y_pred, axis = 1), labels_d)
# Out:
# Accuracy: 1.00
#
# Micro Precision: 1.00
# Micro Recall: 1.00
# Micro F1-score: 1.00
#
# Macro Precision: 0.96
# Macro Recall: 0.96
# Macro F1-score: 0.96
#
# Weighted Precision: 1.00
# Weighted Recall: 1.00
# Weighted F1-score: 1.00
#
# Classification Report
#
#                             precision    recall  f1-score   support
#
#                     BENIGN       1.00      1.00      1.00    105019
#                        Bot       0.98      0.98      0.98       280
#                       DDoS       1.00      1.00      1.00     19271
#              DoS GoldenEye       1.00      1.00      1.00      1542
#                   DoS Hulk       1.00      1.00      1.00     34547
#           DoS Slowhttptest       1.00      1.00      1.00       828
#              DoS slowloris       1.00      0.99      1.00       834
#                FTP-Patator       1.00      1.00      1.00      1178
#                 Heartbleed       1.00      1.00      1.00         2
#               Infiltration       1.00      1.00      1.00         1
#                   PortScan       0.99      1.00      0.99     23846
#                SSH-Patator       1.00      1.00      1.00       826
#   Web Attack � Brute Force       0.93      0.88      0.90       209
# Web Attack � Sql Injection       0.71      0.71      0.71         7
#           Web Attack � XSS       0.77      0.88      0.82        93
#
#                   accuracy                           1.00    188483
#                  macro avg       0.96      0.96      0.96    188483
#               weighted avg       1.00      1.00      1.00    188483

# %% [markdown]
# ### Save the model

# %%
model2d_g.save('cnn2d_78_http80.h5')

# %%
model2d_g.save('/content/drive/My Drive/CICIDS2017/cnn2d_78_http80.h5')
