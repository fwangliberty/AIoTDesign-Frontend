# %% [markdown]
# <a href="https://colab.research.google.com/github/fwangliberty/AIoTDesign-Frontend/blob/master/Classification_CNN1D_68_features_SMOTE_split_1%20(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CNN1D for CICIDS 2017 DataSet with 68 Features and SMOTE
#
#
#
#
# We will not use any categoric features: Source Port, Destination Port and Protocol. We use SMOTE to solve the imbalance dataset.

# %% [markdown]
# We use the pre-processing dataset from mlp4nids (Multi-layer perceptron for network intrusion detection) https://github.com/ArnaudRosay/mlp4nids. In this case, we do not use SMOTE to add more anomalies.

# %%
import os
from os.path import join
import glob
import pandas as pd
import numpy as np
import time
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def display_metrics(y_test, y_pred, label_names):
  print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_test, y_pred)))

  print('Micro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='micro')))
  print('Micro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='micro')))
  print('Micro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='micro')))

  print('Macro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='macro')))
  print('Macro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='macro')))
  print('Macro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='macro')))

  print('Weighted Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='weighted')))
  print('Weighted Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='weighted')))
  print('Weighted F1-score: {:.2f}'.format(f1_score(y_test, y_pred, average='weighted')))

  print('\nClassification Report\n')
  print(classification_report(y_test, y_pred, target_names=label_names))

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 100, "display.max_columns", 100): 
        print(df)

# %%
def make_value2index(attacks):
    #make dictionary
    attacks = sorted(attacks)
    d = {}
    counter=0
    for attack in attacks:
        d[attack] = counter
        counter+=1
    return d

# %%
# chganges label from string to integer/index
def encode_label(Y_str):
    labels_d = make_value2index(np.unique(Y_str))
    Y = [labels_d[y_str] for y_str  in Y_str]
    Y = np.array(Y)
    return np.array(Y)

# %% [markdown]
# ## Step 1. Loading csv files

# %%
# All columns
col_names = ['Source Port', 'Destination Port',
                      'Protocol', 'Flow Duration', 'Total Fwd Packets', 'Total Backward Packets', 'Total Length of Fwd Packets',
                      'Total Length of Bwd Packets', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean',
                      'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std',
                      'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total',
                      'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max',
                      'Bwd IAT Min', 'Fwd PSH Flags', 'Fwd URG Flags', 'Fwd Header Length', 'Bwd Header Length',
                      'Fwd Packets/s', 'Bwd Packets/s', 'Min Packet Length', 'Max Packet Length', 'Packet Length Mean', 'Packet Length Std',
                      'Packet Length Variance', 'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count',
                      'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio', 'Average Packet Size', 'Avg Fwd Segment Size',
                      'Avg Bwd Segment Size','Subflow Fwd Packets', 'Subflow Fwd Bytes',
                      'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward', 'Init_Win_bytes_backward',
                      'act_data_pkt_fwd', 'min_seg_size_forward', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean',
                      'Idle Std', 'Idle Max', 'Idle Min', 'Label']

# %% [markdown]
# ### Option 1. Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# load three csv files generated by mlp4nids (Multi-layer perceptron for network intrusion detection )
# first load the train set
df_train = pd.read_csv('/content/drive/My Drive/CICIDS2017/train_set.csv',names=col_names, skiprows=1)

# %%
df_train.head()
# Out:
#          Source Port  Destination Port  Protocol  ...  Idle Max  Idle Min     Label
# 546863         50203               389        17  ...         0         0    BENIGN
# 2284286        47786                80         6  ...  85500000  85500000  DoS Hulk
# 390020         51520               443         6  ...  58900000  58000000    BENIGN
# 212934         61397                53        17  ...         0         0    BENIGN
# 306030            80             37209         6  ...         0         0    BENIGN
#
# [5 rows x 72 columns]

# %%
df_train=df_train.drop(columns=['Source Port', 'Destination Port', 'Protocol'])

# %%
print('Train set size: ', df_train.shape)
# Out:
# Train set size:  (556548, 69)

# %%
df_test = pd.read_csv('/content/drive/My Drive/CICIDS2017/test_set.csv',names=col_names, skiprows=1)  
df_test=df_test.drop(columns=['Source Port', 'Destination Port', 'Protocol'])
print('Test set size: ', df_test.shape)

df_val = pd.read_csv('/content/drive/My Drive/CICIDS2017/crossval_set.csv',names=col_names, skiprows=1)  
df_val=df_val.drop(columns=['Source Port', 'Destination Port', 'Protocol'])
print('Validation set size: ', df_val.shape)
# Out:
# Test set size:  (278270, 69)
# Validation set size:  (278270, 69)

# %% [markdown]
# ### Option 2. Load from local machine

# %%
dataroot = '../data/cicids2017clean/train_set.csv'
df_train = pd.read_csv(dataroot, names=col_names, skiprows=1)

# %%
dataroot = '../data/cicids2017clean/crossval_set.csv'
df_val = pd.read_csv(dataroot, names=col_names, skiprows=1) 
dataroot = '../data/cicids2017clean/test_set.csv'
df_test = pd.read_csv(dataroot, names=col_names, skiprows=1)

# %% [markdown]
# ## Step 2. Exploring the dataset

# %%
df_train.head()
# Out:
#          Flow Duration  Total Fwd Packets  ...  Idle Min     Label
# 546863             130                  2  ...         0    BENIGN
# 2284286       85594954                  6  ...  85500000  DoS Hulk
# 390020       117915594                 19  ...  58000000    BENIGN
# 212934           30731                  1  ...         0    BENIGN
# 306030              49                  1  ...         0    BENIGN
#
# [5 rows x 69 columns]

# %% [markdown]
# Count the number of attacks

# %%
df_train['Label'].value_counts()
# Out:
# BENIGN                        278274
# DoS Hulk                      115062
# PortScan                       79402
# DDoS                           64012
# DoS GoldenEye                   5146
# FTP-Patator                     3967
# SSH-Patator                     2948
# DoS slowloris                   2898
# DoS Slowhttptest                2749
# Bot                              978
# Web Attack � Brute Force         753
# Web Attack � XSS                 326
# Infiltration                      18
# Web Attack � Sql Injection        10
# Heartbleed                         5
# Name: Label, dtype: int64

# %%
df_train.describe()
# Out:
#        Flow Duration  Total Fwd Packets  ...      Idle Max      Idle Min
# count   5.565480e+05      556548.000000  ...  5.565480e+05  5.565480e+05
# mean    2.159931e+07           7.561386  ...  1.730500e+07  1.552621e+07
# std     3.824665e+07         641.917381  ...  3.390042e+07  3.259279e+07
# min    -1.300000e+01           1.000000  ...  0.000000e+00  0.000000e+00
# 25%     1.120000e+02           1.000000  ...  0.000000e+00  0.000000e+00
# 50%     6.867450e+04           2.000000  ...  0.000000e+00  0.000000e+00
# 75%     1.104332e+07           6.000000  ...  9.803576e+06  7.462839e+06
# max     1.199999e+08      207964.000000  ...  1.200000e+08  1.200000e+08
#
# [8 rows x 68 columns]

# %% [markdown]
# Read test and validation sets

# %%
print('Test set: ')
df_test['Label'].value_counts()
# Out:
# Test set:
# BENIGN                        139135
# DoS Hulk                       57531
# PortScan                       39701
# DDoS                           32006
# DoS GoldenEye                   2573
# FTP-Patator                     1983
# SSH-Patator                     1474
# DoS slowloris                   1449
# DoS Slowhttptest                1374
# Bot                              489
# Web Attack � Brute Force         376
# Web Attack � XSS                 163
# Infiltration                       9
# Web Attack � Sql Injection         5
# Heartbleed                         2
# Name: Label, dtype: int64

# %%
df_test.describe()
# Out:
#        Flow Duration  Total Fwd Packets  ...      Idle Max      Idle Min
# count   2.782700e+05      278270.000000  ...  2.782700e+05  2.782700e+05
# mean    2.018494e+07          13.425781  ...  1.461183e+07  1.319746e+07
# std     3.747672e+07        1208.778536  ...  3.158812e+07  3.024680e+07
# min    -1.000000e+00           1.000000  ...  0.000000e+00  0.000000e+00
# 25%     8.000000e+01           2.000000  ...  0.000000e+00  0.000000e+00
# 50%     8.538300e+04           3.000000  ...  0.000000e+00  0.000000e+00
# 75%     9.936814e+06           7.000000  ...  5.860882e+06  5.499876e+06
# max     1.199999e+08      219759.000000  ...  1.199946e+08  1.199946e+08
#
# [8 rows x 68 columns]

# %%
print('Validation set: ')
df_val['Label'].value_counts()
# Out:
# Validation set:
# BENIGN                        139135
# DoS Hulk                       57531
# PortScan                       39701
# DDoS                           32006
# DoS GoldenEye                   2573
# FTP-Patator                     1983
# SSH-Patator                     1474
# DoS slowloris                   1449
# DoS Slowhttptest                1374
# Bot                              489
# Web Attack � Brute Force         376
# Web Attack � XSS                 163
# Infiltration                       9
# Web Attack � Sql Injection         5
# Heartbleed                         2
# Name: Label, dtype: int64

# %%
df_val.describe()
# Out:
#        Flow Duration  Total Fwd Packets  ...      Idle Max      Idle Min
# count   2.782700e+05      278270.000000  ...  2.782700e+05  2.782700e+05
# mean    2.267720e+07           5.697168  ...  1.829755e+07  1.689405e+07
# std     3.957518e+07          67.142466  ...  3.540421e+07  3.437331e+07
# min    -1.200000e+01           1.000000  ...  0.000000e+00  0.000000e+00
# 25%     8.700000e+01           1.000000  ...  0.000000e+00  0.000000e+00
# 50%     4.852000e+04           2.000000  ...  0.000000e+00  0.000000e+00
# 75%     1.181203e+07           6.000000  ...  9.992129e+06  7.454226e+06
# max     1.200000e+08       16412.000000  ...  1.200000e+08  1.200000e+08
#
# [8 rows x 68 columns]

# %% [markdown]
# ## Step 3. Encode Datasets

# %% [markdown]
# Encoding the labels, and generate numpy array. Note that the label has not been encoded as one-hot coding. We will use one-hot code later.

# %% [markdown]
# ### Step 3.1 Encoding train dataset

# %%
df_label = df_train['Label']
data = df_train.drop(columns=['Label'])
Xtrain = data.values
y_train = encode_label(df_label.values)

# %% [markdown]
# ### Step 3.2. SMOTE train data set

# %%
label = encode_label(df_label.values)
bb=label.reshape(label.shape[0],)    
y10 = np.int32(bb)

# %%
from collections import Counter

sorted(Counter(y10).items())
# Out:
# [(0, 278274),
#  (1, 978),
#  (2, 64012),
#  (3, 5146),
#  (4, 115062),
#  (5, 2749),
#  (6, 2898),
#  (7, 3967),
#  (8, 5),
#  (9, 18),
#  (10, 79402),
#  (11, 2948),
#  (12, 753),
#  (13, 10),
#  (14, 326)]

# %% [markdown]
# To use SMOTE, the default number of nearest neighbours in SMOTE must be changed according to the dataset. For train dataset, the least class type has 5 examples. So, we need to change the k_neighbors parameter to 4 (5 neighbors) to construct synthetic samples.

# %%
from imblearn.over_sampling import SMOTE
import time
time_start = time.time()

guo = 5000  #Oversampling samples

smo = SMOTE(sampling_strategy={1:guo,5:guo,6:guo,7:guo,8:guo,9:guo,11:guo,12:guo,13:guo,14:guo},random_state=42,k_neighbors=4)

Xtrain_smo, ytrain_smo = smo.fit_sample(Xtrain, y10)   
print(sorted(Counter(ytrain_smo).items()))

time_end = time.time()
time = time_end - time_start
print("time:",time)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# [(0, 278274), (1, 5000), (2, 64012), (3, 5146), (4, 115062), (5, 5000), (6, 5000), (7, 5000), (8, 5000), (9, 5000), (10, 79402), (11, 5000), (12, 5000), (13, 5000), (14, 5000)]
# time: 1.862170696258545
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
Xtrain_smo.shape
# Out:
# (591896, 68)

# %%
ytrain_smo.shape
# Out:
# (591896,)

# %%
sorted(Counter(ytrain_smo).items())
# Out:
# [(0, 278274),
#  (1, 5000),
#  (2, 64012),
#  (3, 5146),
#  (4, 115062),
#  (5, 5000),
#  (6, 5000),
#  (7, 5000),
#  (8, 5000),
#  (9, 5000),
#  (10, 79402),
#  (11, 5000),
#  (12, 5000),
#  (13, 5000),
#  (14, 5000)]

# %% [markdown]
# ### Step 3.3. Encoding test dataset

# %%
df_label = df_test['Label']
data = df_test.drop(columns=['Label'])
Xtest = data.values
y_test = encode_label(df_label.values)

# %% [markdown]
# ### Step 3.4 Encoding validation dataset

# %%
df_label = df_val['Label']
data = df_val.drop(columns=['Label'])
Xval = data.values
y_val = encode_label(df_label.values)

# %% [markdown]
# ## Step 4. Normalization or Standardization
#
# The continuous feature values are normalized into the same feature space. This is important when using features that have different measurements, and is a general requirement of many machine learning algorithms. We implement the two methods to see the impact on the final classifications.

# %% [markdown]
# ## Option 1. Normalization
#
# The values of the datasets are normalized using the Min-Max scaling technique, bringing them all within a range of [0,1].

# %% [markdown]
# ### Step 4.1 Normalizing train dataset

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(Xtrain_smo)
X_train
# Out:
# array([[1.19166704e-06, 4.80854767e-06, 7.02735750e-06, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [7.13291618e-01, 2.40427384e-05, 2.10820725e-05, ...,
#         0.00000000e+00, 7.12500000e-01, 7.12500000e-01],
#        [9.82630369e-01, 8.65538581e-05, 5.97325388e-05, ...,
#         8.96864890e-03, 4.90833333e-01, 4.83333333e-01],
#        ...,
#        [4.45104009e-02, 9.61709535e-06, 3.51367875e-06, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.93696651e-02, 2.06486971e-05, 1.70862350e-05, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.47203305e-02, 9.61709535e-06, 3.51367875e-06, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %% [markdown]
# ### Step 4.2. Normalizing validation dataset

# %%
X_val = scaler.fit_transform(Xval)
X_val
# Out:
# array([[9.11674962e-03, 1.82804217e-04, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [5.08333312e-07, 0.00000000e+00, 4.91980714e-05, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [6.28146249e-01, 1.15776004e-03, 1.13155564e-03, ...,
#         5.68691207e-05, 8.33333333e-02, 8.32947583e-02],
#        ...,
#        [1.01176662e-03, 0.00000000e+00, 4.91980714e-05, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.58333314e-07, 0.00000000e+00, 4.91980714e-05, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00521829e-02, 1.21869478e-04, 1.96792286e-04, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %% [markdown]
# ### Step 4.3. Normalizing test dataset

# %%
X_test = scaler.fit_transform(Xtest)
X_test
# Out:
# array([[3.58333608e-07, 0.00000000e+00, 3.42557258e-06, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.16666986e-08, 4.55046005e-06, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.50000345e-07, 0.00000000e+00, 3.42557258e-06, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [8.35847991e-01, 2.73027603e-05, 2.05534355e-05, ...,
#         0.00000000e+00, 8.33370661e-01, 8.33370661e-01],
#        [5.04708720e-04, 0.00000000e+00, 3.42557258e-06, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [9.92561411e-01, 6.96220388e-04, 1.12701338e-03, ...,
#         5.01804492e-03, 4.88761059e-01, 4.84412289e-01]])

# %% [markdown]
# ## Option 2. **Standardization**
#
# Select the standardization could cause more accuracy.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(Xtrain_smo)
X_val = scaler.fit_transform(Xval)
X_test = scaler.fit_transform(Xtest)

X_train
# Out:
# array([[-0.57479565, -0.06191553, -0.04306541, ..., -0.17038878,
#         -0.50042262, -0.46387563],
#        [ 1.60802471, -0.05628063, -0.038569  , ..., -0.17038878,
#          2.06662771,  2.20930602],
#        [ 2.43225856, -0.03796718, -0.02620387, ..., -0.07700984,
#          1.26798983,  1.34951075],
#        ...,
#        [-0.438588  , -0.06050681, -0.04418951, ..., -0.17038878,
#         -0.50042262, -0.46387563],
#        [-0.42371762, -0.05727496, -0.03984735, ..., -0.17038878,
#         -0.50042262, -0.46387563],
#        [-0.43794557, -0.06050681, -0.04418951, ..., -0.17038878,
#         -0.50042262, -0.46387563]])

# %% [markdown]
# ## Step 5 One-hot encoding for labels

# %% [markdown]
# y_train, y_test and y_val have to be one-hot-encoded. That means they must have dimension (number_of_samples, 15), where 15 denotes number of classes.

# %%
from tensorflow.keras.utils import to_categorical

# %%
y_train = to_categorical(ytrain_smo, 15)
y_test = to_categorical(y_test, 15)
y_val = to_categorical(y_val, 15)

# %% [markdown]
# ## Step 6. Define the metrics

# %%
import tensorflow as tf
from sklearn.ensemble import RandomForestClassifier

#importing confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from sklearn import metrics
from sklearn.metrics import accuracy_score

#importing accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %% [markdown]
# Get the attacks' names

# %%
labels_d = make_value2index(df_test['Label'])

# %%
print(labels_d)
# Out:
# {'BENIGN': 139134, 'Bot': 139623, 'DDoS': 171629, 'DoS GoldenEye': 174202, 'DoS Hulk': 231733, 'DoS Slowhttptest': 233107, 'DoS slowloris': 234556, 'FTP-Patator': 236539, 'Heartbleed': 236541, 'Infiltration': 236550, 'PortScan': 276251, 'SSH-Patator': 277725, 'Web Attack � Brute Force': 278101, 'Web Attack � Sql Injection': 278106, 'Web Attack � XSS': 278269}

# %% [markdown]
# # CNN1D Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, Flatten, Dense, Activation,Dropout,MaxPooling1D
from tensorflow.keras.constraints import max_norm

# %%
#hyper-params
batch_size = 6000 # increasing batch size with more gpu added
input_dim = X_train.shape[1]
num_class = 15                   # 15 intrusion classes, including benign traffic class
num_epochs = 30
learning_rates = 1e-4
regularizations = 1e-3
optim = tf.keras.optimizers.Adam(lr=learning_rates, beta_1=0.9, beta_2=0.999, epsilon=1e-8)

print(input_dim)
print(num_class)
# Out:
# 68
# 15

# %%
#X_train_r = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train_r = np.zeros((len(X_train), input_dim, 1))
X_train_r[:, :, 0] = X_train[:, :input_dim]
print(X_train_r.shape)
# Out:
# (591896, 68, 1)

# %%
X_test_r = np.zeros((len(X_test), input_dim, 1))
X_test_r[:, :, 0] = X_test[:, :input_dim]
print(X_test_r.shape)
# Out:
# (278270, 68, 1)

# %%
X_val_r = np.zeros((len(X_val), input_dim, 1))
X_val_r[:, :, 0] = X_val[:, :input_dim]
print(X_val_r.shape)
# Out:
# (278270, 68, 1)

# %%
model = Sequential()

# input layer
model.add(Conv1D(filters=32, kernel_size=17, activation='relu', padding='same', kernel_initializer='he_uniform', input_shape=(68,1)))
model.add(Conv1D(filters=32, kernel_size=11, activation='relu', padding='same', kernel_initializer='he_uniform'))
model.add(MaxPooling1D(pool_size=2,strides=2))
model.add(Dropout(0.3))
model.add(BatchNormalization(axis=1))

model.add(Conv1D(filters=64, kernel_size=17, activation='relu', padding='same', kernel_initializer='he_uniform'))
model.add(Conv1D(filters=64, kernel_size=11, activation='relu', padding='same', kernel_initializer='he_uniform'))
model.add(MaxPooling1D(pool_size=2,strides=2))
model.add(Dropout(0.3))
model.add(BatchNormalization(axis=1)) 

model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(num_class))
model.add(Activation('softmax'))


model.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_96 (Conv1D)           (None, 68, 32)            576
# _________________________________________________________________
# conv1d_97 (Conv1D)           (None, 68, 32)            11296
# _________________________________________________________________
# max_pooling1d_48 (MaxPooling (None, 34, 32)            0
# _________________________________________________________________
# dropout_72 (Dropout)         (None, 34, 32)            0
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 34, 32)            136
# _________________________________________________________________
# conv1d_98 (Conv1D)           (None, 34, 64)            34880
# _________________________________________________________________
# conv1d_99 (Conv1D)           (None, 34, 64)            45120
# _________________________________________________________________
# max_pooling1d_49 (MaxPooling (None, 17, 64)            0
# _________________________________________________________________
# dropout_73 (Dropout)         (None, 17, 64)            0
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 17, 64)            68
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 1088)              0
# _________________________________________________________________
# dense_48 (Dense)             (None, 32)                34848
# _________________________________________________________________
# dropout_74 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_49 (Dense)             (None, 15)                495
# _________________________________________________________________
# activation_24 (Activation)   (None, 15)                0
# =================================================================
# Total params: 127,419
# Trainable params: 127,317
# Non-trainable params: 102
# _________________________________________________________________

# %%
from keras.optimizers import Nadam
from keras.callbacks import LearningRateScheduler, ModelCheckpoint
import keras
import time
time_start = time.time()

reduce_lr = keras.callbacks.ReduceLROnPlateau(moniter='val_loss',
                                              factor=0.1,
                                              patience=10)
nadam = Nadam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, schedule_decay=0.0001)
model.compile(loss = "categorical_crossentropy",optimizer = "nadam", metrics = ["accuracy"])

history = model.fit(X_train_r, y_train, 
                    epochs=100, 
                    batch_size=batch_size, 
                    verbose=2,
                    validation_data=(X_val_r, y_val),
                    callbacks=[reduce_lr])
time_end = time.time()
train_time = time_end - time_start
print("train_time:",train_time)
# Out:
# Epoch 1/100
# 99/99 - 8s - loss: 0.6082 - accuracy: 0.8251 - val_loss: 0.3215 - val_accuracy: 0.9417
# Epoch 2/100
# 99/99 - 6s - loss: 0.1961 - accuracy: 0.9331 - val_loss: 0.2015 - val_accuracy: 0.9406
# Epoch 3/100
# 99/99 - 6s - loss: 0.1458 - accuracy: 0.9467 - val_loss: 0.1688 - val_accuracy: 0.9378
# Epoch 4/100
# 99/99 - 6s - loss: 0.1215 - accuracy: 0.9544 - val_loss: 0.1367 - val_accuracy: 0.9547
# Epoch 5/100
# 99/99 - 6s - loss: 0.1098 - accuracy: 0.9584 - val_loss: 0.1203 - val_accuracy: 0.9571
# Epoch 6/100
# 99/99 - 6s - loss: 0.1023 - accuracy: 0.9607 - val_loss: 0.1251 - val_accuracy: 0.9567
# Epoch 7/100
# 99/99 - 6s - loss: 0.0975 - accuracy: 0.9622 - val_loss: 0.1217 - val_accuracy: 0.9615
# Epoch 8/100
# 99/99 - 6s - loss: 0.0934 - accuracy: 0.9634 - val_loss: 0.1301 - val_accuracy: 0.9640
# Epoch 9/100
# 99/99 - 6s - loss: 0.0900 - accuracy: 0.9644 - val_loss: 0.1325 - val_accuracy: 0.9614
# Epoch 10/100
# 99/99 - 6s - loss: 0.0885 - accuracy: 0.9648 - val_loss: 0.1455 - val_accuracy: 0.9643
# Epoch 11/100
# 99/99 - 6s - loss: 0.0863 - accuracy: 0.9654 - val_loss: 0.1222 - val_accuracy: 0.9621
# Epoch 12/100
# 99/99 - 6s - loss: 0.0844 - accuracy: 0.9660 - val_loss: 0.1397 - val_accuracy: 0.9611
# Epoch 13/100
# 99/99 - 6s - loss: 0.2160 - accuracy: 0.9319 - val_loss: 0.1368 - val_accuracy: 0.9563
# Epoch 14/100
# 99/99 - 6s - loss: 0.0967 - accuracy: 0.9625 - val_loss: 0.1223 - val_accuracy: 0.9619
# Epoch 15/100
# 99/99 - 6s - loss: 0.0882 - accuracy: 0.9651 - val_loss: 0.1370 - val_accuracy: 0.9581
# Epoch 16/100
# 99/99 - 6s - loss: 0.0837 - accuracy: 0.9666 - val_loss: 0.1319 - val_accuracy: 0.9612
# Epoch 17/100
# 99/99 - 6s - loss: 0.0822 - accuracy: 0.9671 - val_loss: 0.1368 - val_accuracy: 0.9650
# Epoch 18/100
# 99/99 - 6s - loss: 0.0818 - accuracy: 0.9673 - val_loss: 0.1380 - val_accuracy: 0.9627
# Epoch 19/100
# 99/99 - 6s - loss: 0.0815 - accuracy: 0.9673 - val_loss: 0.1390 - val_accuracy: 0.9650
# Epoch 20/100
# 99/99 - 6s - loss: 0.0809 - accuracy: 0.9675 - val_loss: 0.1421 - val_accuracy: 0.9651
# Epoch 21/100
# 99/99 - 6s - loss: 0.0807 - accuracy: 0.9677 - val_loss: 0.1470 - val_accuracy: 0.9654
# Epoch 22/100
# 99/99 - 6s - loss: 0.0805 - accuracy: 0.9675 - val_loss: 0.1424 - val_accuracy: 0.9658
# Epoch 23/100
# 99/99 - 6s - loss: 0.0795 - accuracy: 0.9679 - val_loss: 0.1467 - val_accuracy: 0.9633
# Epoch 24/100
# 99/99 - 6s - loss: 0.0790 - accuracy: 0.9680 - val_loss: 0.1466 - val_accuracy: 0.9633
# Epoch 25/100
# 99/99 - 6s - loss: 0.0789 - accuracy: 0.9681 - val_loss: 0.1474 - val_accuracy: 0.9636
# Epoch 26/100
# 99/99 - 6s - loss: 0.0786 - accuracy: 0.9683 - val_loss: 0.1486 - val_accuracy: 0.9636
# Epoch 27/100
# 99/99 - 6s - loss: 0.0782 - accuracy: 0.9684 - val_loss: 0.1495 - val_accuracy: 0.9636
# Epoch 28/100
# 99/99 - 6s - loss: 0.0781 - accuracy: 0.9687 - val_loss: 0.1503 - val_accuracy: 0.9636
# Epoch 29/100
# 99/99 - 6s - loss: 0.0782 - accuracy: 0.9683 - val_loss: 0.1503 - val_accuracy: 0.9659
# Epoch 30/100
# 99/99 - 6s - loss: 0.0779 - accuracy: 0.9686 - val_loss: 0.1518 - val_accuracy: 0.9658
# Epoch 31/100
# 99/99 - 6s - loss: 0.0776 - accuracy: 0.9685 - val_loss: 0.1512 - val_accuracy: 0.9658
# Epoch 32/100
# 99/99 - 6s - loss: 0.0780 - accuracy: 0.9686 - val_loss: 0.1510 - val_accuracy: 0.9660
# Epoch 33/100
# 99/99 - 6s - loss: 0.0778 - accuracy: 0.9687 - val_loss: 0.1515 - val_accuracy: 0.9659
# Epoch 34/100
# 99/99 - 6s - loss: 0.0779 - accuracy: 0.9687 - val_loss: 0.1518 - val_accuracy: 0.9659
# Epoch 35/100
# 99/99 - 6s - loss: 0.0779 - accuracy: 0.9688 - val_loss: 0.1516 - val_accuracy: 0.9659
# Epoch 36/100
# 99/99 - 6s - loss: 0.0777 - accuracy: 0.9688 - val_loss: 0.1515 - val_accuracy: 0.9659
# Epoch 37/100
# 99/99 - 6s - loss: 0.0779 - accuracy: 0.9687 - val_loss: 0.1519 - val_accuracy: 0.9658
# Epoch 38/100
# 99/99 - 6s - loss: 0.0777 - accuracy: 0.9687 - val_loss: 0.1522 - val_accuracy: 0.9659
# Epoch 39/100
# 99/99 - 6s - loss: 0.0775 - accuracy: 0.9688 - val_loss: 0.1525 - val_accuracy: 0.9658
# Epoch 40/100
# 99/99 - 6s - loss: 0.0776 - accuracy: 0.9687 - val_loss: 0.1526 - val_accuracy: 0.9659
# Epoch 41/100
# 99/99 - 6s - loss: 0.0775 - accuracy: 0.9688 - val_loss: 0.1527 - val_accuracy: 0.9658
# Epoch 42/100
# 99/99 - 6s - loss: 0.0777 - accuracy: 0.9686 - val_loss: 0.1529 - val_accuracy: 0.9660
# Epoch 43/100
# 99/99 - 6s - loss: 0.0771 - accuracy: 0.9688 - val_loss: 0.1530 - val_accuracy: 0.9660
# Epoch 44/100
# 99/99 - 6s - loss: 0.0774 - accuracy: 0.9688 - val_loss: 0.1524 - val_accuracy: 0.9659
# Epoch 45/100
# 99/99 - 6s - loss: 0.0774 - accuracy: 0.9688 - val_loss: 0.1527 - val_accuracy: 0.9660
# Epoch 46/100
# 99/99 - 6s - loss: 0.0773 - accuracy: 0.9689 - val_loss: 0.1529 - val_accuracy: 0.9660
# Epoch 47/100
# 99/99 - 6s - loss: 0.0776 - accuracy: 0.9688 - val_loss: 0.1530 - val_accuracy: 0.9658
# Epoch 48/100
# 99/99 - 6s - loss: 0.0776 - accuracy: 0.9687 - val_loss: 0.1529 - val_accuracy: 0.9660
# Epoch 49/100
# 99/99 - 6s - loss: 0.0775 - accuracy: 0.9689 - val_loss: 0.1531 - val_accuracy: 0.9659
# Epoch 50/100
# 99/99 - 6s - loss: 0.0776 - accuracy: 0.9687 - val_loss: 0.1532 - val_accuracy: 0.9659
# Epoch 51/100
# 99/99 - 6s - loss: 0.0778 - accuracy: 0.9686 - val_loss: 0.1528 - val_accuracy: 0.9658
# Epoch 52/100
# 99/99 - 6s - loss: 0.0778 - accuracy: 0.9686 - val_loss: 0.1530 - val_accuracy: 0.9659
# Epoch 53/100
# 99/99 - 6s - loss: 0.0777 - accuracy: 0.9688 - val_loss: 0.1528 - val_accuracy: 0.9659
# Epoch 54/100
# 99/99 - 6s - loss: 0.0774 - accuracy: 0.9688 - val_loss: 0.1532 - val_accuracy: 0.9659
# Epoch 55/100
# 99/99 - 6s - loss: 0.0774 - accuracy: 0.9688 - val_loss: 0.1529 - val_accuracy: 0.9659
# Epoch 56/100
# 99/99 - 6s - loss: 0.0772 - accuracy: 0.9690 - val_loss: 0.1528 - val_accuracy: 0.9659
# Epoch 57/100
# 99/99 - 6s - loss: 0.0773 - accuracy: 0.9688 - val_loss: 0.1532 - val_accuracy: 0.9659
# Epoch 58/100
# 99/99 - 6s - loss: 0.0772 - accuracy: 0.9688 - val_loss: 0.1532 - val_accuracy: 0.9659
# Epoch 59/100
# 99/99 - 6s - loss: 0.0775 - accuracy: 0.9688 - val_loss: 0.1532 - val_accuracy: 0.9659
# Epoch 60/100
# 99/99 - 6s - loss: 0.0774 - accuracy: 0.9688 - val_loss: 0.1528 - val_accuracy: 0.9659
# Epoch 61/100
# 99/99 - 6s - loss: 0.0774 - accuracy: 0.9687 - val_loss: 0.1532 - val_accuracy: 0.9660
# Epoch 62/100
# 99/99 - 6s - loss: 0.0774 - accuracy: 0.9688 - val_loss: 0.1530 - val_accuracy: 0.9659
# Epoch 63/100
# 99/99 - 6s - loss: 0.0781 - accuracy: 0.9686 - val_loss: 0.1530 - val_accuracy: 0.9659
# Epoch 64/100
# 99/99 - 6s - loss: 0.0776 - accuracy: 0.9688 - val_loss: 0.1530 - val_accuracy: 0.9660
# Epoch 65/100
# 99/99 - 6s - loss: 0.0778 - accuracy: 0.9687 - val_loss: 0.1532 - val_accuracy: 0.9659
# Epoch 66/100
# 99/99 - 6s - loss: 0.0778 - accuracy: 0.9687 - val_loss: 0.1530 - val_accuracy: 0.9659
# Epoch 67/100
# 99/99 - 6s - loss: 0.0778 - accuracy: 0.9686 - val_loss: 0.1529 - val_accuracy: 0.9659
# Epoch 68/100
# 99/99 - 6s - loss: 0.0776 - accuracy: 0.9688 - val_loss: 0.1530 - val_accuracy: 0.9659
# Epoch 69/100
# 99/99 - 6s - loss: 0.0780 - accuracy: 0.9686 - val_loss: 0.1534 - val_accuracy: 0.9658
# Epoch 70/100
# 99/99 - 6s - loss: 0.0775 - accuracy: 0.9686 - val_loss: 0.1533 - val_accuracy: 0.9659
# Epoch 71/100
# 99/99 - 6s - loss: 0.0775 - accuracy: 0.9687 - val_loss: 0.1534 - val_accuracy: 0.9659
# Epoch 72/100
# 99/99 - 6s - loss: 0.0777 - accuracy: 0.9687 - val_loss: 0.1531 - val_accuracy: 0.9660
# Epoch 73/100
# 99/99 - 6s - loss: 0.0777 - accuracy: 0.9687 - val_loss: 0.1530 - val_accuracy: 0.9660
# Epoch 74/100
# 99/99 - 6s - loss: 0.0777 - accuracy: 0.9687 - val_loss: 0.1532 - val_accuracy: 0.9660
# Epoch 75/100
# 99/99 - 6s - loss: 0.0774 - accuracy: 0.9687 - val_loss: 0.1531 - val_accuracy: 0.9660
# Epoch 76/100
# 99/99 - 6s - loss: 0.0774 - accuracy: 0.9688 - val_loss: 0.1532 - val_accuracy: 0.9660
# Epoch 77/100
# 99/99 - 6s - loss: 0.0777 - accuracy: 0.9687 - val_loss: 0.1529 - val_accuracy: 0.9659
# Epoch 78/100
# 99/99 - 6s - loss: 0.0776 - accuracy: 0.9686 - val_loss: 0.1528 - val_accuracy: 0.9658
# Epoch 79/100
# 99/99 - 6s - loss: 0.0774 - accuracy: 0.9686 - val_loss: 0.1529 - val_accuracy: 0.9659
# Epoch 80/100
# 99/99 - 6s - loss: 0.0777 - accuracy: 0.9687 - val_loss: 0.1532 - val_accuracy: 0.9659
# Epoch 81/100
# 99/99 - 6s - loss: 0.0777 - accuracy: 0.9688 - val_loss: 0.1532 - val_accuracy: 0.9659
# Epoch 82/100
# 99/99 - 6s - loss: 0.0778 - accuracy: 0.9688 - val_loss: 0.1531 - val_accuracy: 0.9659
# Epoch 83/100
# 99/99 - 6s - loss: 0.0778 - accuracy: 0.9687 - val_loss: 0.1532 - val_accuracy: 0.9660
# Epoch 84/100
# 99/99 - 6s - loss: 0.0776 - accuracy: 0.9687 - val_loss: 0.1530 - val_accuracy: 0.9659
# Epoch 85/100
# 99/99 - 6s - loss: 0.0779 - accuracy: 0.9687 - val_loss: 0.1530 - val_accuracy: 0.9659
# Epoch 86/100
# 99/99 - 6s - loss: 0.0773 - accuracy: 0.9687 - val_loss: 0.1531 - val_accuracy: 0.9659
# Epoch 87/100
# 99/99 - 6s - loss: 0.0776 - accuracy: 0.9688 - val_loss: 0.1532 - val_accuracy: 0.9659
# Epoch 88/100
# 99/99 - 6s - loss: 0.0777 - accuracy: 0.9687 - val_loss: 0.1534 - val_accuracy: 0.9659
# Epoch 89/100
# 99/99 - 6s - loss: 0.0776 - accuracy: 0.9687 - val_loss: 0.1531 - val_accuracy: 0.9659
# Epoch 90/100
# 99/99 - 6s - loss: 0.0780 - accuracy: 0.9688 - val_loss: 0.1533 - val_accuracy: 0.9660
# Epoch 91/100
# 99/99 - 6s - loss: 0.0773 - accuracy: 0.9688 - val_loss: 0.1530 - val_accuracy: 0.9660
# Epoch 92/100
# 99/99 - 6s - loss: 0.0774 - accuracy: 0.9689 - val_loss: 0.1530 - val_accuracy: 0.9659
# Epoch 93/100
# 99/99 - 6s - loss: 0.0777 - accuracy: 0.9687 - val_loss: 0.1531 - val_accuracy: 0.9659
# Epoch 94/100
# 99/99 - 6s - loss: 0.0778 - accuracy: 0.9687 - val_loss: 0.1531 - val_accuracy: 0.9659
# Epoch 95/100
# 99/99 - 6s - loss: 0.0776 - accuracy: 0.9689 - val_loss: 0.1534 - val_accuracy: 0.9659
# Epoch 96/100
# 99/99 - 6s - loss: 0.0775 - accuracy: 0.9688 - val_loss: 0.1533 - val_accuracy: 0.9659
# Epoch 97/100
# 99/99 - 6s - loss: 0.0779 - accuracy: 0.9688 - val_loss: 0.1531 - val_accuracy: 0.9659
# Epoch 98/100
# 99/99 - 6s - loss: 0.0777 - accuracy: 0.9687 - val_loss: 0.1529 - val_accuracy: 0.9659
# Epoch 99/100
# 99/99 - 6s - loss: 0.0776 - accuracy: 0.9688 - val_loss: 0.1531 - val_accuracy: 0.9659
# Epoch 100/100
# 99/99 - 6s - loss: 0.0775 - accuracy: 0.9689 - val_loss: 0.1528 - val_accuracy: 0.9659
# train_time: 586.6645896434784

# %% [markdown]
# ## Get the metrics

# %%
# evaluate model
accuracy = model.evaluate(X_test_r, y_test, batch_size=batch_size, verbose=1)
# Out:
# 47/47 [==============================] - 1s 15ms/step - loss: 0.3573 - accuracy: 0.9300

# %%
y_pred=model.predict(X_test_r)

# %%
display_metrics(y_test_ada, np.argmax(y_pred, axis = 1), labels_d)
# Out:
# Accuracy: 0.93
#
# Micro Precision: 0.93
# Micro Recall: 0.93
# Micro F1-score: 0.93
#
# Macro Precision: 0.57
# Macro Recall: 0.62
# Macro F1-score: 0.56
#
# Weighted Precision: 0.94
# Weighted Recall: 0.93
# Weighted F1-score: 0.93
#
# Classification Report
#
#                             precision    recall  f1-score   support
#
#                     BENIGN       0.98      0.90      0.94    139135
#                        Bot       0.00      0.00      0.00       489
#                       DDoS       0.78      1.00      0.88     32006
#              DoS GoldenEye       0.93      0.84      0.88      2573
#                   DoS Hulk       0.92      0.96      0.94     57531
#           DoS Slowhttptest       0.64      0.77      0.70      1374
#              DoS slowloris       0.87      0.44      0.59      1449
#                FTP-Patator       0.81      0.98      0.89      1983
#                 Heartbleed       0.50      1.00      0.67         2
#               Infiltration       0.00      0.00      0.00         9
#                   PortScan       1.00      1.00      1.00     39701
#                SSH-Patator       0.99      0.49      0.66      1474
#   Web Attack � Brute Force       0.00      0.00      0.00       376
# Web Attack � Sql Injection       0.00      0.00      0.00         5
#           Web Attack � XSS       0.13      0.91      0.23       163
#
#                   accuracy                           0.93    278270
#                  macro avg       0.57      0.62      0.56    278270
#               weighted avg       0.94      0.93      0.93    278270
